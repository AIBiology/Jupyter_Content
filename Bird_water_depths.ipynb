# %% [markdown]
# # 1. photo recognition birds

# %%
# uplaod images of wading birds for training

# identify species and if they stand in water

# identify legs

# %% [markdown]
# # 2. measure water from bird mophology

# %%
# use avonet for traits of wading birds: https://opentraits.org/datasets/avonet.html

# identify leg length and water depth for each image
