# %% [markdown]
# # Vision Transformers
#
# Not too long after Vaswani *et al.*'s [*Attention is all you need*](https://arxiv.org/abs/1706.03762) paper started revolutionizing NLP models, people started to wonder if transformers could be applied to other domains.
#
# In 2021 the Alexey Dosovitskiy *et al.* (from Google Brain) published a preprint called [*An Image is Worth 16x16 Words: Transformers for Image Recognition at Scale*](https://arxiv.org/abs/2010.11929) where they applied transformers to computer vision. Thier intro starts:
#
# > Self-attention-based architectures, in particular Transformers (Vaswani et al., 2017), have become the model of choice in natural language processing (NLP). The dominant approach is to pre-train on a large text corpus and then fine-tune on a smaller task-specific dataset (Devlin et al., 2019). Thanks to Transformers’ computational efficiency and scalability, it has become possible to train models of unprecedented size, with over 100B parameters (Brown et al., 2020; Lepikhin et al., 2020). With the models and datasets growing, there is still no sign of saturating performance.
#
# After noting that some attempts to apply transformers to computer vision had not been terribly successful, largely because they continued to use CNN-like approaches, Dosovitskiy *et al.* state:
#
# > Inspired by the Transformer scaling successes in NLP, we experiment with applying a standard Transformer directly to images, with the fewest possible modifications. To do so, we split an image into patches and provide the sequence of linear embeddings of these patches as an input to a Transformer. Image patches are treated the same way as tokens (words) in an NLP application. We train the model on image classification in supervised fashion.
#
# And while they find that with smaller datasets, results are less than stellar, Dosovitskiy *et al.* find that their Vision Transformer (ViT):
#
# > When pre-trained on the public ImageNet-21k dataset or the in-house JFT-300M dataset, ViT approaches or beats state of the art on multiple image recognition benchmarks. In particular, the best model reaches the accuracy of 88.55% on ImageNet, 90.72% on ImageNet-ReaL, 94.55% on CIFAR-100, and 77.63% on the VTAB suite of 19 tasks.
#
# Here's figure 1 from Dosovitskiy *et al.* (2021):
#
# ![Figure 1 from Dosovitskiy *et al.* 2021 ViT architecture](images/ViT_architecture.png)

# %% [markdown]
# ## First a word about Python modules and Jupyter kernels...
#
# Before getting into using transformers, we need to learn a bit more about Python modules and Jupyter kernels. Check out [this page on the class website](https://aibiology.github.io/vit_mamba_setup.html).
#
# ## And now, three options...
#
#
# ### Option 1
#
# The first is in this notebook and is from  Philipp Schmid's blog post [*Image Classification with Hugging Face Transformers and `Keras`*](https://www.philschmid.de/image-classification-huggingface-transformers-keras). The problem is, and I might have tried subsampling the data if I had more time, is that it takes about 1-hour per epoch to train as it is.
#
# ### Option 2
#
# The second example, which I think we'll use in class is in notebook [21b_vit-fine-tuning.ipynb](21b_vit-fine-tuning.ipynb) and is from [Ruaf Momin's Kaggle notebook](https://www.kaggle.com/code/raufmomin/vision-transformer-vit-fine-tuning).
#
# ### Option 3
# The [21c_Vision-transformers.ipynb](21c_Vision-transformers.ipynb) ] notebook has been adapted based on an official [keras example](https://github.com/keras-team/keras-io/tree/master/examples/vision) of using vision transformers for image classification, and demonstrates it on the [CIFAR-100 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).
#
#
# ### General observation
#
# And a general observation about both options...While both options use fine tuning of a ViT mobel, neither freezes the weights of the main ViT model as we did in transfer learning. Honestly don't know if that's an oversight, strategy, or what.
#
#
# ## Option 1

# %% [markdown]
# Much of this example comes from Philipp Schmid's blog post [*Image Classification with Hugging Face Transformers and `Keras`*](https://www.philschmid.de/image-classification-huggingface-transformers-keras).
#
# This example uses the EuroSAT satellite images from [here](https://github.com/phelber/eurosat) published in:
# * Eurosat: A novel dataset and deep learning benchmark for land use and land cover classification. Patrick Helber, Benjamin Bischke, Andreas Dengel, Damian Borth. IEEE Journal of Selected Topics in Applied Earth Observations and Remote Sensing, 2019. [https://doi.org/10.48550/arXiv.1709.00029](https://doi.org/10.48550/arXiv.1709.00029)
#
# *  Introducing EuroSAT: A Novel Dataset and Deep Learning Benchmark for Land Use and Land Cover Classification. Patrick Helber, Benjamin Bischke, Andreas Dengel. 2018 IEEE International Geoscience and Remote Sensing Symposium, 2018. [https://doi.org/10.1109/IGARSS.2018.8519248](https://doi.org/10.1109/IGARSS.2018.8519248)
#
# For the class, the dataset has been installed at: `/blue/bsc48926/share/EuroSAT_RGB/`
#
# Here's the description of the data and a composite image of patches:
#
# > In this study, we address the challenge of land use and land cover classification using Sentinel-2 satellite images. The Sentinel-2 satellite images are openly and freely accessible provided in the Earth observation program Copernicus. We present a novel dataset based on Sentinel-2 satellite images covering 13 spectral bands and consisting out of 10 classes with in total 27,000 labeled and geo-referenced images.
#
# ![EuroSAT image](https://github.com/phelber/EuroSAT/raw/master/eurosat_overview_small.jpg?raw=true)
#
# The land use classes are: `AnnualCrop`,  `Forest`,  `HerbaceousVegetation`,  `Highway`,  `Industrial`,  `Pasture`,  `PermanentCrop`,  `Residential`,  `River`,  `SeaLake`.

# %% [markdown]
# ## Import modules
#
# I have opted to stick with the image loading and processing pipeline used by Phillip rather than try to convert this to use the `image_dataset_from_directory`, which I *think* should work...

# %%
import os
os.environ["KERAS_BACKEND"] = "torch"

import math
import random
from pathlib import Path

import keras
import matplotlib.pyplot as plt
import numpy as np
from keras import layers, ops
from PIL import Image
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader

keras.utils.set_random_seed(42)
print("Keras:", keras.__version__, "| backend:", keras.backend.backend())
# Out:
# Keras: 3.8.0 | backend: torch

# %%
eurosat_path = Path("/blue/bsc4892/share/EuroSAT_RGB/")
image_size = 64
input_shape = (image_size, image_size, 3)
patch_size = 8
batch_size = 256
epochs = 15
learning_rate = 3e-4
weight_decay = 1e-4
test_size = 0.15

if not eurosat_path.exists():
    raise FileNotFoundError(
        f"Could not find {eurosat_path}. Update `eurosat_path` to the local EuroSAT folder."
    )

# %%
from sklearn.model_selection import train_test_split

def collect_image_records(root):
    class_names = sorted([p.name for p in root.iterdir() if p.is_dir()])
    class_to_idx = {name: i for i, name in enumerate(class_names)}
    records = []
    for class_name in class_names:
        for image_path in sorted((root / class_name).glob("*")):
            if image_path.suffix.lower() in {".jpg", ".jpeg", ".png", ".tif", ".tiff"}:
                records.append((str(image_path), class_to_idx[class_name]))
    return records, class_names, class_to_idx

records, class_names, class_to_idx = collect_image_records(eurosat_path)

demo_fraction = 0.15  # keep 20% of the data

records_demo, _ = train_test_split(
    records,
    train_size=demo_fraction,
    random_state=42,
    stratify=[label for _, label in records],
)

train_records, test_records = train_test_split(
    records_demo,
    test_size=test_size,
    random_state=42,
    stratify=[label for _, label in records_demo],
)

print("Classes:", class_names)
print("Demo total images:", len(records_demo))
print("Train images:", len(train_records))
print("Test images:", len(test_records))
# Out:
# Classes: ['AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway', 'Industrial', 'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake']
# Demo total images: 4050
# Train images: 3442
# Test images: 608

# %%
class FolderImageDataset(Dataset):
    def __init__(self, records, image_size, augment=False):
        self.records = records
        self.image_size = image_size
        self.augment = augment

    def __len__(self):
        return len(self.records)

    def _augment(self, image):
        if random.random() < 0.5:
            image = image.transpose(Image.Transpose.FLIP_LEFT_RIGHT)
        if random.random() < 0.5:
            image = image.transpose(Image.Transpose.FLIP_TOP_BOTTOM)
        if random.random() < 0.25:
            image = image.transpose(Image.Transpose.TRANSPOSE)
        if random.random() < 0.25:
            image = image.rotate(random.choice([90, 180, 270]))
        return image

    def __getitem__(self, idx):
        image_path, label = self.records[idx]
        image = Image.open(image_path).convert("RGB").resize(
            (self.image_size, self.image_size)
        )
        if self.augment:
            image = self._augment(image)
        image = np.asarray(image, dtype="float32") / 255.0
        return image, np.int64(label)

train_ds = FolderImageDataset(train_records, image_size=image_size, augment=True)
test_ds = FolderImageDataset(test_records, image_size=image_size, augment=False)

train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=0)
test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=0)

# %%
images, labels = next(iter(train_loader))
fig, axes = plt.subplots(3, 5, figsize=(10, 8))
for ax, image, label in zip(axes.flatten(), images[:15], labels[:15]):
    ax.imshow(image)
    ax.set_title(class_names[int(label)])
    ax.axis("off")
plt.tight_layout()
plt.show()

# %%
@keras.saving.register_keras_serializable()
class Patches(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        patches = ops.image.extract_patches(
            images,
            size=(self.patch_size, self.patch_size),
            strides=(self.patch_size, self.patch_size),
        )
        batch_size = ops.shape(images)[0]
        patch_dims = patches.shape[-1]
        return ops.reshape(patches, (batch_size, -1, patch_dims))

    def get_config(self):
        return {"patch_size": self.patch_size, **super().get_config()}


@keras.saving.register_keras_serializable()
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.projection_dim = projection_dim
        self.projection = layers.Dense(projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches,
            output_dim=projection_dim,
        )

    def call(self, patches):
        positions = ops.arange(start=0, stop=self.num_patches, step=1)
        return self.projection(patches) + self.position_embedding(positions)

    def get_config(self):
        return {
            "num_patches": self.num_patches,
            "projection_dim": self.projection_dim,
            **super().get_config(),
        }


def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=keras.activations.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x


def create_vit_classifier(
    input_shape,
    image_size,
    patch_size,
    num_classes,
    projection_dim=64,
    transformer_layers=8,
    num_heads=4,
    transformer_units=(128, 64),
    mlp_head_units=(256, 128),
    augmentation=None,
):
    num_patches = (image_size // patch_size) ** 2
    inputs = keras.Input(shape=input_shape)
    x = inputs
    if augmentation is not None:
        x = augmentation(x)
    else:
        x = layers.Resizing(image_size, image_size)(x)

    patches = Patches(patch_size)(x)
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    for _ in range(transformer_layers):
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads,
            key_dim=projection_dim,
            dropout=0.1,
        )(x1, x1)
        x2 = layers.Add()([attention_output, encoded_patches])

        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        encoded_patches = layers.Add()([x3, x2])

    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.3)(representation)
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.3)
    logits = layers.Dense(num_classes)(features)
    return keras.Model(inputs=inputs, outputs=logits)

# %%
data_augmentation = keras.Sequential(
    [
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.02),
        layers.RandomZoom(0.1),
    ],
    name="data_augmentation",
)

model = create_vit_classifier(
    input_shape=input_shape,
    image_size=image_size,
    patch_size=patch_size,
    num_classes=len(class_names),
    projection_dim=64,
    transformer_layers=6,
    num_heads=4,
    transformer_units=(128, 64),
    mlp_head_units=(256, 128),
    augmentation=data_augmentation,
)

model.compile(
    optimizer=keras.optimizers.AdamW(
        learning_rate=learning_rate,
        weight_decay=weight_decay,
    ),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[
        keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
        keras.metrics.SparseTopKCategoricalAccuracy(3, name="top_3_accuracy"),
    ],
)
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ data_augmentation   │ (None, 64, 64, 3) │          0 │ input_layer_2[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ patches_1 (Patches) │ (None, 64, 192)   │          0 │ data_augmentatio… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ patch_encoder_1     │ (None, 64, 64)    │     16,448 │ patches_1[0][0]   │
# │ (PatchEncoder)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 64)    │        128 │ patch_encoder_1[… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 64, 64)    │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 64, 64)    │          0 │ multi_head_atten… │
# │                     │                   │            │ patch_encoder_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 64)    │        128 │ add_12[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 64, 128)   │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 64, 128)   │          0 │ dense_17[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 64, 64)    │      8,256 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 64, 64)    │          0 │ dense_18[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 64, 64)    │          0 │ dropout_23[0][0], │
# │                     │                   │            │ add_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 64)    │        128 │ add_13[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 64, 64)    │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 64, 64)    │          0 │ multi_head_atten… │
# │                     │                   │            │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 64)    │        128 │ add_14[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 64, 128)   │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 64, 128)   │          0 │ dense_19[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 64, 64)    │      8,256 │ dropout_25[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 64, 64)    │          0 │ dense_20[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 64, 64)    │          0 │ dropout_26[0][0], │
# │                     │                   │            │ add_14[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 64)    │        128 │ add_15[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 64, 64)    │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 64, 64)    │          0 │ multi_head_atten… │
# │                     │                   │            │ add_15[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 64)    │        128 │ add_16[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 64, 128)   │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_28          │ (None, 64, 128)   │          0 │ dense_21[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 64, 64)    │      8,256 │ dropout_28[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_29          │ (None, 64, 64)    │          0 │ dense_22[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 64, 64)    │          0 │ dropout_29[0][0], │
# │                     │                   │            │ add_16[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 64)    │        128 │ add_17[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 64, 64)    │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 64, 64)    │          0 │ multi_head_atten… │
# │                     │                   │            │ add_17[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 64)    │        128 │ add_18[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 64, 128)   │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_31          │ (None, 64, 128)   │          0 │ dense_23[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_24 (Dense)    │ (None, 64, 64)    │      8,256 │ dropout_31[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_32          │ (None, 64, 64)    │          0 │ dense_24[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, 64, 64)    │          0 │ dropout_32[0][0], │
# │                     │                   │            │ add_18[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 64)    │        128 │ add_19[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 64, 64)    │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, 64, 64)    │          0 │ multi_head_atten… │
# │                     │                   │            │ add_19[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 64)    │        128 │ add_20[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_25 (Dense)    │ (None, 64, 128)   │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_34          │ (None, 64, 128)   │          0 │ dense_25[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_26 (Dense)    │ (None, 64, 64)    │      8,256 │ dropout_34[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_35          │ (None, 64, 64)    │          0 │ dense_26[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_21 (Add)        │ (None, 64, 64)    │          0 │ dropout_35[0][0], │
# │                     │                   │            │ add_20[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 64)    │        128 │ add_21[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 64, 64)    │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_22 (Add)        │ (None, 64, 64)    │          0 │ multi_head_atten… │
# │                     │                   │            │ add_21[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 64)    │        128 │ add_22[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_27 (Dense)    │ (None, 64, 128)   │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_37          │ (None, 64, 128)   │          0 │ dense_27[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_28 (Dense)    │ (None, 64, 64)    │      8,256 │ dropout_37[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_38          │ (None, 64, 64)    │          0 │ dense_28[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_23 (Add)        │ (None, 64, 64)    │          0 │ dropout_38[0][0], │
# │                     │                   │            │ add_22[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 64)    │        128 │ add_23[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 4096)      │          0 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_39          │ (None, 4096)      │          0 │ flatten_1[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_29 (Dense)    │ (None, 256)       │  1,048,832 │ dropout_39[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_40          │ (None, 256)       │          0 │ dense_29[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_30 (Dense)    │ (None, 128)       │     32,896 │ dropout_40[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_41          │ (None, 128)       │          0 │ dense_30[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_31 (Dense)    │ (None, 10)        │      1,290 │ dropout_41[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,598,794 (6.10 MB)
#  Trainable params: 1,598,794 (6.10 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_accuracy",
        patience=2,
        restore_best_weights=True,
    )
]

history = model.fit(
    train_loader,
    validation_data=test_loader,
    epochs=epochs,
    callbacks=callbacks,
)
# Out:
# Epoch 1/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 498ms/step - accuracy: 0.1267 - loss: 2.6852 - top_3_accuracy: 0.3397 - val_accuracy: 0.2516 - val_loss: 1.9688 - val_top_3_accuracy: 0.5395
# Epoch 2/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 507ms/step - accuracy: 0.2076 - loss: 2.0906 - top_3_accuracy: 0.5180 - val_accuracy: 0.3076 - val_loss: 1.8928 - val_top_3_accuracy: 0.5970
# Epoch 3/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 491ms/step - accuracy: 0.2493 - loss: 1.9831 - top_3_accuracy: 0.5739 - val_accuracy: 0.3322 - val_loss: 1.7966 - val_top_3_accuracy: 0.6266
# Epoch 4/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 497ms/step - accuracy: 0.2654 - loss: 1.9494 - top_3_accuracy: 0.5864 - val_accuracy: 0.3010 - val_loss: 1.8162 - val_top_3_accuracy: 0.6760
# Epoch 5/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 498ms/step - accuracy: 0.2615 - loss: 1.9311 - top_3_accuracy: 0.5771 - val_accuracy: 0.3553 - val_loss: 1.7619 - val_top_3_accuracy: 0.6595
# Epoch 6/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 494ms/step - accuracy: 0.2798 - loss: 1.8867 - top_3_accuracy: 0.6100 - val_accuracy: 0.3668 - val_loss: 1.6949 - val_top_3_accuracy: 0.6562
# Epoch 7/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 486ms/step - accuracy: 0.3437 - loss: 1.7870 - top_3_accuracy: 0.6559 - val_accuracy: 0.4408 - val_loss: 1.6219 - val_top_3_accuracy: 0.7072
# Epoch 8/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 494ms/step - accuracy: 0.3526 - loss: 1.7801 - top_3_accuracy: 0.6743 - val_accuracy: 0.4556 - val_loss: 1.5388 - val_top_3_accuracy: 0.7401
# Epoch 9/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 487ms/step - accuracy: 0.3841 - loss: 1.7027 - top_3_accuracy: 0.6999 - val_accuracy: 0.4737 - val_loss: 1.5067 - val_top_3_accuracy: 0.7500
# Epoch 10/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 490ms/step - accuracy: 0.4130 - loss: 1.6581 - top_3_accuracy: 0.7122 - val_accuracy: 0.4885 - val_loss: 1.4327 - val_top_3_accuracy: 0.7878
# Epoch 11/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 488ms/step - accuracy: 0.4133 - loss: 1.6143 - top_3_accuracy: 0.7226 - val_accuracy: 0.4901 - val_loss: 1.3959 - val_top_3_accuracy: 0.8010
# Epoch 12/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 491ms/step - accuracy: 0.4373 - loss: 1.5679 - top_3_accuracy: 0.7515 - val_accuracy: 0.5016 - val_loss: 1.3802 - val_top_3_accuracy: 0.8174
# Epoch 13/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 490ms/step - accuracy: 0.4442 - loss: 1.5260 - top_3_accuracy: 0.7554 - val_accuracy: 0.5214 - val_loss: 1.4154 - val_top_3_accuracy: 0.8076
# Epoch 14/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 497ms/step - accuracy: 0.4577 - loss: 1.5314 - top_3_accuracy: 0.7628 - val_accuracy: 0.5016 - val_loss: 1.4172 - val_top_3_accuracy: 0.8092
# Epoch 15/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 502ms/step - accuracy: 0.4644 - loss: 1.5326 - top_3_accuracy: 0.7662 - val_accuracy: 0.5115 - val_loss: 1.3238 - val_top_3_accuracy: 0.8125

# %%
results = model.evaluate(test_loader, verbose=1)
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.4f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5166 - loss: 1.4307 - top_3_accuracy: 0.8032
# loss: 1.4154
# compile_metrics: 0.5214

# %%
# ── Training curves ──────────────────────────────────────────────────────────
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(history.history['accuracy'],     label='train')
ax1.plot(history.history['val_accuracy'], label='val')
ax1.set_title('Accuracy')
ax1.legend()

ax2.plot(history.history['loss'],     label='train')
ax2.plot(history.history['val_loss'], label='val')
ax2.set_title('Loss')
ax2.legend()

plt.tight_layout()
plt.show()
