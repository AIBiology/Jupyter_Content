# %% [markdown]
# # From neuron to neural net
#
# Last time, we looked at a single neuron. We discussed the parallels between that neuron with two weights and linear regression. As we add more features (columns in our X matrix), we can add more neurons.
#
# ## Activation Functions
#
# However, as we add neurons, each neuron still mostly functions like linear regression. The next thing we can add to our neuron is an **activation function**. Activation functions adjust the output of a neuron by adding some function before the final output. Below are the "linear" activation function that we have modeled so far, plus the more common **ReLU (Rectified Linear Unit)** and **Sigmoid** activation functions.
#
# ![Diagrams of the linear, ReLU and Sigmoid activation functions](images/Activation_function_diagrams.png)
#
#
# Again, the activation function is applied to the output of a neuron and is a hyperparameter of the model. In practice, while layers may use different activation functions, the same function is applied to **all neurons** of each layer. Below is a single neuron with a couple of possible activation functions.
#
# ![Diagram of a neuron with activation function](images/Activation_function.png)
#
# ## Layers
#
# As we get multiple neurons, we need some way of coordinating their output so we can add a layer to gather the output from multiple neurons into the needed number of outputs (more on that later). However, the other thing that layers do is allow deeper networks with multiple layers, each selected for functional or empirical reasons. This is where deep learning gets its name--as networks grow to have more and more layers of neurons, we refer to them as deep networks--there is no agreed-upon cutoff here...more than three???
#
# ![A two layer neural network](images/Neural_network.png)

# %%
import pandas as pd
import numpy as np

import os
os.environ['KERAS_BACKEND'] = 'torch'
import keras
from keras import layers
from keras.optimizers import Adam

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('data/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Get our X and y
X = df.drop(columns='Outcome')
y = df['Outcome']

# %%
# Scale data - mean 0 std dev 1

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
model = keras.Sequential([
    layers.Dense(8, input_dim=8, activation='relu'),
    layers.Dense(1, activation='sigmoid')
    ])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 81 (324.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
lr = 0.001  # Set the learning rate. Start with default for Adam, 0.001
optimizer = Adam(learning_rate=lr)  # Set the optimizer. Start with adam.

# Compile the model--a necessary step with Keras models
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
# Now we can fit the model
# Let's also save the training history for plotting

history = model.fit(X, y, epochs=150, validation_split=0.25, batch_size=10, verbose=1)
# Out:
# Epoch 1/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5769 - loss: 0.7037 - val_accuracy: 0.6042 - val_loss: 0.6733
# Epoch 2/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6039 - loss: 0.6620 - val_accuracy: 0.6510 - val_loss: 0.6300
# Epoch 3/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7027 - loss: 0.6060 - val_accuracy: 0.6927 - val_loss: 0.5986
# Epoch 4/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7090 - loss: 0.6153 - val_accuracy: 0.7031 - val_loss: 0.5750
# Epoch 5/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7419 - loss: 0.5361 - val_accuracy: 0.7188 - val_loss: 0.5567
# Epoch 6/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7535 - loss: 0.5507 - val_accuracy: 0.7240 - val_loss: 0.5436
# Epoch 7/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7512 - loss: 0.5290 - val_accuracy: 0.7344 - val_loss: 0.5325
# Epoch 8/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7341 - loss: 0.5106 - val_accuracy: 0.7396 - val_loss: 0.5219
# Epoch 9/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7447 - loss: 0.5120 - val_accuracy: 0.7500 - val_loss: 0.5129
# Epoch 10/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7740 - loss: 0.4761 - val_accuracy: 0.7552 - val_loss: 0.5059
# Epoch 11/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7369 - loss: 0.4928 - val_accuracy: 0.7604 - val_loss: 0.4997
# Epoch 12/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7853 - loss: 0.4734 - val_accuracy: 0.7552 - val_loss: 0.4944
# Epoch 13/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7606 - loss: 0.5259 - val_accuracy: 0.7604 - val_loss: 0.4911
# Epoch 14/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7281 - loss: 0.5144 - val_accuracy: 0.7708 - val_loss: 0.4873
# Epoch 15/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8023 - loss: 0.4452 - val_accuracy: 0.8021 - val_loss: 0.4496
# Epoch 122/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7533 - loss: 0.4822 - val_accuracy: 0.8021 - val_loss: 0.4500
# Epoch 123/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7853 - loss: 0.4507 - val_accuracy: 0.8073 - val_loss: 0.4504
# Epoch 124/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7836 - loss: 0.4618 - val_accuracy: 0.8021 - val_loss: 0.4495
# Epoch 125/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8058 - loss: 0.4447 - val_accuracy: 0.8021 - val_loss: 0.4497
# Epoch 126/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7692 - loss: 0.4652 - val_accuracy: 0.8021 - val_loss: 0.4499
# Epoch 127/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7513 - loss: 0.5073 - val_accuracy: 0.8021 - val_loss: 0.4497
# Epoch 128/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7923 - loss: 0.4524 - val_accuracy: 0.8021 - val_loss: 0.4505
# Epoch 129/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7920 - loss: 0.4531 - val_accuracy: 0.8021 - val_loss: 0.4516
# Epoch 130/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7745 - loss: 0.4436 - val_accuracy: 0.8021 - val_loss: 0.4508
# Epoch 131/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7907 - loss: 0.4475 - val_accuracy: 0.8021 - val_loss: 0.4508
# Epoch 132/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7807 - loss: 0.4454 - val_accuracy: 0.8021 - val_loss: 0.4498
# Epoch 133/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7966 - loss: 0.4405 - val_accuracy: 0.8021 - val_loss: 0.4508
# Epoch 134/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7880 - loss: 0.4546 - val_accuracy: 0.8021 - val_loss: 0.4521
# Epoch 135/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7640 - loss: 0.4983 - val_accuracy: 0.8021 - val_loss: 0.4513
# Epoch 136/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7980 - loss: 0.4444 - val_accuracy: 0.7969 - val_loss: 0.4520
# Epoch 137/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7978 - loss: 0.4343 - val_accuracy: 0.8021 - val_loss: 0.4513
# Epoch 138/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8000 - loss: 0.4439 - val_accuracy: 0.7969 - val_loss: 0.4517
# Epoch 139/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7643 - loss: 0.4590 - val_accuracy: 0.8021 - val_loss: 0.4517
# Epoch 140/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7901 - loss: 0.4593 - val_accuracy: 0.8021 - val_loss: 0.4516
# Epoch 141/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7880 - loss: 0.4839 - val_accuracy: 0.7969 - val_loss: 0.4514
# Epoch 142/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8094 - loss: 0.4198 - val_accuracy: 0.7969 - val_loss: 0.4513
# Epoch 143/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7887 - loss: 0.4422 - val_accuracy: 0.7969 - val_loss: 0.4510
# Epoch 144/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7820 - loss: 0.4604 - val_accuracy: 0.7917 - val_loss: 0.4530
# Epoch 145/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7688 - loss: 0.4813 - val_accuracy: 0.7917 - val_loss: 0.4521
# Epoch 146/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7959 - loss: 0.4453 - val_accuracy: 0.7969 - val_loss: 0.4521
# Epoch 147/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7704 - loss: 0.4660 - val_accuracy: 0.7917 - val_loss: 0.4520
# Epoch 148/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7847 - loss: 0.4407 - val_accuracy: 0.7969 - val_loss: 0.4513
# Epoch 149/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7811 - loss: 0.4630 - val_accuracy: 0.7969 - val_loss: 0.4512
# Epoch 150/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7894 - loss: 0.4730 - val_accuracy: 0.7917 - val_loss: 0.4505

# %%
# Make some nice plots

from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Experimentation
#
# Using what you know so far, try to make the best possible model to predict diabetes with these data.
#
# Things to try:
#
# * Try normalizing data (all values between 0 and 1)
#     ```python
#     # Normalize data - all between 0 and 1
#     scaler = MinMaxScaler()
#     X = scaler.fit_transform(X)
#     ```
# * Adding layers
# * Adjusting the number of neurons per layer (you do need to get back to 1 with a sigmoid activation at the end)
# * Different activation functions
# * Adjusting the number of epochs
# * Adjusting learning rate
