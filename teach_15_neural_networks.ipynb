# %% [markdown]
# # From neuron to neural net
#
# Last time, we looked at a single neuron. We discussed the parallels between that neuron with two weights and linear regression. As we add more features (columns in our X matrix) we can add more neurons.
#
# ## Activation Functions
#
# But, as we add neurons, each neuron is still mostly functioning like linear regression. The next thing we can add to our neuron is an **activation function**. Activation functions adjust the output of a neuron by adding some function before the final output. Below are the "linear" activation function that we have modeled so far, plus the more common **ReLU (Rectified Linear Unit)** and **Sigmoid** activation functions.
#
# ![Diagrams of the linear, ReLU and Sigmoid activation functions](images/Activation_function_diagrams.png)
#
#
# Again, the activation function is applied to the output of a neuron and is a hyperparameter of the model. In practice, while layers may use different activation functions, the same function is applied to **all neurons** of each layer. Below is a single neuron, with the a couple possible activation functions.
#
# ![Diagram of a neuron with activation function](images/Activation_function.png)
#
# ## Layers
#
# As we get multiple neurons, we need some way of coordinating their output, so we can add a layer to gather the output from multiple neurons into the needed number of outputs (more on that later). But the other thing that layers do is allow deeper networks with multiple layers, each selected for functional or empirical reasons. This is where deep learning gets its name--as networks grow to have more and more layers of neurons, we refer to them as deep networks--there is no agreed upon cutoff here...more than three???
#
# ![A two layer neural network](images/Neural_network.png)

# %%
import tensorflow as tf
import pandas as pd
import numpy as np

from tensorflow import keras
from tensorflow.keras import layers

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('data/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Get our X and y
X = df.drop(columns='Outcome')
y = df['Outcome']

# %%
# Scale data - mean 0 std dev 1

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
model = keras.Sequential([
    layers.Dense(8, input_dim=8, activation='relu'),
    layers.Dense(1, activation='sigmoid')
    ])

model.summary()
# Out:
# 2022-02-28 08:40:52.078090: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 8)                 72
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 81
# Trainable params: 81
# Non-trainable params: 0
# _________________________________________________________________
# 2022-02-28 08:40:52.568818: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79125 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:07:00.0, compute capability: 8.0

# %%
# Set some model hyperparameters
from tensorflow.keras.optimizers import Adam

lr = 0.001  # Set the learning rate. Start with default for Adam, 0.001
optimizer = Adam(learning_rate=lr)  # Set the optimizer. Start with adam.

# Compile the model--a necessary step with Keras models
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
# Now we can fit the model
# Let's also save the training history for plotting

history = model.fit(X, y, epochs=150, validation_split=0.25, batch_size=10, verbose=1)
# Out:
# Epoch 1/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4525 - accuracy: 0.7778 - val_loss: 0.4403 - val_accuracy: 0.7865
# Epoch 2/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4517 - accuracy: 0.7812 - val_loss: 0.4403 - val_accuracy: 0.7865
# Epoch 3/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4521 - accuracy: 0.7778 - val_loss: 0.4390 - val_accuracy: 0.7917
# Epoch 4/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4509 - accuracy: 0.7795 - val_loss: 0.4388 - val_accuracy: 0.7865
# Epoch 5/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4507 - accuracy: 0.7830 - val_loss: 0.4386 - val_accuracy: 0.7865
# Epoch 6/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4502 - accuracy: 0.7830 - val_loss: 0.4387 - val_accuracy: 0.7812
# Epoch 7/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4497 - accuracy: 0.7830 - val_loss: 0.4395 - val_accuracy: 0.7760
# Epoch 8/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4492 - accuracy: 0.7812 - val_loss: 0.4387 - val_accuracy: 0.7812
# Epoch 9/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4492 - accuracy: 0.7865 - val_loss: 0.4390 - val_accuracy: 0.7865
# Epoch 10/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4484 - accuracy: 0.7830 - val_loss: 0.4385 - val_accuracy: 0.7865
# Epoch 11/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4484 - accuracy: 0.7882 - val_loss: 0.4387 - val_accuracy: 0.7760
# Epoch 12/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4476 - accuracy: 0.7847 - val_loss: 0.4381 - val_accuracy: 0.7812
# Epoch 13/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4475 - accuracy: 0.7865 - val_loss: 0.4380 - val_accuracy: 0.7812
# Epoch 14/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4468 - accuracy: 0.7865 - val_loss: 0.4381 - val_accuracy: 0.7812
# Epoch 15/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4466 - accuracy: 0.7865 - val_loss: 0.4393 - val_accuracy: 0.7812
# Epoch 16/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4464 - accuracy: 0.7882 - val_loss: 0.4369 - val_accuracy: 0.7917
# Epoch 17/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4461 - accuracy: 0.7865 - val_loss: 0.4392 - val_accuracy: 0.7917
# Epoch 18/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4455 - accuracy: 0.7865 - val_loss: 0.4376 - val_accuracy: 0.7812
# Epoch 19/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4459 - accuracy: 0.7917 - val_loss: 0.4368 - val_accuracy: 0.7812
# Epoch 20/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4448 - accuracy: 0.7882 - val_loss: 0.4376 - val_accuracy: 0.7812
# Epoch 21/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4447 - accuracy: 0.7847 - val_loss: 0.4375 - val_accuracy: 0.7812
# Epoch 22/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4441 - accuracy: 0.7865 - val_loss: 0.4380 - val_accuracy: 0.7865
# Epoch 23/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4439 - accuracy: 0.7847 - val_loss: 0.4387 - val_accuracy: 0.7865
# Epoch 24/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4434 - accuracy: 0.7865 - val_loss: 0.4380 - val_accuracy: 0.7812
# Epoch 25/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4433 - accuracy: 0.7917 - val_loss: 0.4376 - val_accuracy: 0.7812
# Epoch 26/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4432 - accuracy: 0.7882 - val_loss: 0.4381 - val_accuracy: 0.7865
# Epoch 27/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4424 - accuracy: 0.7865 - val_loss: 0.4381 - val_accuracy: 0.7812
# Epoch 28/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4421 - accuracy: 0.7899 - val_loss: 0.4381 - val_accuracy: 0.7812
# Epoch 29/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4421 - accuracy: 0.7865 - val_loss: 0.4389 - val_accuracy: 0.7865
# Epoch 30/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4421 - accuracy: 0.7917 - val_loss: 0.4379 - val_accuracy: 0.7812
# Epoch 31/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4413 - accuracy: 0.7917 - val_loss: 0.4381 - val_accuracy: 0.7812
# Epoch 32/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4415 - accuracy: 0.7899 - val_loss: 0.4381 - val_accuracy: 0.7812
# Epoch 33/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4412 - accuracy: 0.7882 - val_loss: 0.4393 - val_accuracy: 0.7865
# Epoch 34/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4407 - accuracy: 0.7934 - val_loss: 0.4380 - val_accuracy: 0.7812
# Epoch 35/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4407 - accuracy: 0.7934 - val_loss: 0.4372 - val_accuracy: 0.7812
# Epoch 36/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4403 - accuracy: 0.7934 - val_loss: 0.4380 - val_accuracy: 0.7812
# Epoch 37/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4397 - accuracy: 0.7969 - val_loss: 0.4384 - val_accuracy: 0.7917
# Epoch 38/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4398 - accuracy: 0.7934 - val_loss: 0.4391 - val_accuracy: 0.7917
# Epoch 39/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4394 - accuracy: 0.7969 - val_loss: 0.4381 - val_accuracy: 0.7917
# Epoch 40/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4398 - accuracy: 0.7934 - val_loss: 0.4390 - val_accuracy: 0.7865
# Epoch 41/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4388 - accuracy: 0.7899 - val_loss: 0.4388 - val_accuracy: 0.7865
# Epoch 42/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4390 - accuracy: 0.7951 - val_loss: 0.4397 - val_accuracy: 0.7917
# Epoch 43/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4387 - accuracy: 0.7899 - val_loss: 0.4395 - val_accuracy: 0.7917
# Epoch 44/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4382 - accuracy: 0.7934 - val_loss: 0.4391 - val_accuracy: 0.7865
# Epoch 45/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4384 - accuracy: 0.7951 - val_loss: 0.4390 - val_accuracy: 0.7969
# Epoch 46/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4378 - accuracy: 0.7951 - val_loss: 0.4395 - val_accuracy: 0.7917
# Epoch 47/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4379 - accuracy: 0.7986 - val_loss: 0.4390 - val_accuracy: 0.7969
# Epoch 48/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4374 - accuracy: 0.8003 - val_loss: 0.4383 - val_accuracy: 0.7969
# Epoch 49/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4372 - accuracy: 0.7969 - val_loss: 0.4394 - val_accuracy: 0.8021
# Epoch 50/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4371 - accuracy: 0.8003 - val_loss: 0.4385 - val_accuracy: 0.8021
# Epoch 51/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4367 - accuracy: 0.8003 - val_loss: 0.4396 - val_accuracy: 0.8021
# Epoch 52/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4369 - accuracy: 0.7969 - val_loss: 0.4392 - val_accuracy: 0.7969
# Epoch 53/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4368 - accuracy: 0.8038 - val_loss: 0.4403 - val_accuracy: 0.7969
# Epoch 54/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4359 - accuracy: 0.7969 - val_loss: 0.4394 - val_accuracy: 0.8021
# Epoch 55/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4360 - accuracy: 0.7986 - val_loss: 0.4394 - val_accuracy: 0.8021
# Epoch 56/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4354 - accuracy: 0.7986 - val_loss: 0.4399 - val_accuracy: 0.8073
# Epoch 57/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4352 - accuracy: 0.7986 - val_loss: 0.4399 - val_accuracy: 0.8073
# Epoch 58/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4352 - accuracy: 0.8003 - val_loss: 0.4400 - val_accuracy: 0.8073
# Epoch 59/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4344 - accuracy: 0.8003 - val_loss: 0.4402 - val_accuracy: 0.8073
# Epoch 60/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4344 - accuracy: 0.7969 - val_loss: 0.4394 - val_accuracy: 0.7969
# Epoch 61/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4341 - accuracy: 0.7986 - val_loss: 0.4403 - val_accuracy: 0.8073
# Epoch 62/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4344 - accuracy: 0.7986 - val_loss: 0.4400 - val_accuracy: 0.8073
# Epoch 63/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4341 - accuracy: 0.8003 - val_loss: 0.4401 - val_accuracy: 0.7969
# Epoch 64/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4336 - accuracy: 0.7969 - val_loss: 0.4419 - val_accuracy: 0.8021
# Epoch 65/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4336 - accuracy: 0.8003 - val_loss: 0.4407 - val_accuracy: 0.8021
# Epoch 66/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4325 - accuracy: 0.8021 - val_loss: 0.4403 - val_accuracy: 0.8021
# Epoch 67/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4329 - accuracy: 0.8003 - val_loss: 0.4403 - val_accuracy: 0.8021
# Epoch 68/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4326 - accuracy: 0.8038 - val_loss: 0.4408 - val_accuracy: 0.8021
# Epoch 69/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4322 - accuracy: 0.8038 - val_loss: 0.4407 - val_accuracy: 0.8021
# Epoch 70/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4324 - accuracy: 0.8038 - val_loss: 0.4418 - val_accuracy: 0.8073
# Epoch 71/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4318 - accuracy: 0.8038 - val_loss: 0.4414 - val_accuracy: 0.8073
# Epoch 72/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4313 - accuracy: 0.8003 - val_loss: 0.4422 - val_accuracy: 0.8073
# Epoch 73/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4308 - accuracy: 0.8056 - val_loss: 0.4425 - val_accuracy: 0.8021
# Epoch 74/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4314 - accuracy: 0.8056 - val_loss: 0.4403 - val_accuracy: 0.7969
# Epoch 75/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4308 - accuracy: 0.8003 - val_loss: 0.4424 - val_accuracy: 0.8073
# Epoch 76/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4308 - accuracy: 0.8038 - val_loss: 0.4410 - val_accuracy: 0.8073
# Epoch 77/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4299 - accuracy: 0.8038 - val_loss: 0.4412 - val_accuracy: 0.8073
# Epoch 78/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4300 - accuracy: 0.7969 - val_loss: 0.4420 - val_accuracy: 0.8021
# Epoch 79/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4305 - accuracy: 0.7969 - val_loss: 0.4421 - val_accuracy: 0.8021
# Epoch 80/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4293 - accuracy: 0.8021 - val_loss: 0.4412 - val_accuracy: 0.8177
# Epoch 81/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4291 - accuracy: 0.8021 - val_loss: 0.4423 - val_accuracy: 0.8073
# Epoch 82/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4283 - accuracy: 0.8038 - val_loss: 0.4427 - val_accuracy: 0.8125
# Epoch 83/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4287 - accuracy: 0.8021 - val_loss: 0.4428 - val_accuracy: 0.8125
# Epoch 84/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4282 - accuracy: 0.8021 - val_loss: 0.4429 - val_accuracy: 0.8177
# Epoch 85/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4281 - accuracy: 0.8038 - val_loss: 0.4433 - val_accuracy: 0.8177
# Epoch 86/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4277 - accuracy: 0.8038 - val_loss: 0.4414 - val_accuracy: 0.8073
# Epoch 87/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4281 - accuracy: 0.7986 - val_loss: 0.4440 - val_accuracy: 0.8073
# Epoch 88/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4279 - accuracy: 0.8056 - val_loss: 0.4427 - val_accuracy: 0.8125
# Epoch 89/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4280 - accuracy: 0.7969 - val_loss: 0.4427 - val_accuracy: 0.8073
# Epoch 90/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4274 - accuracy: 0.8021 - val_loss: 0.4433 - val_accuracy: 0.8125
# Epoch 91/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4266 - accuracy: 0.8108 - val_loss: 0.4441 - val_accuracy: 0.8177
# Epoch 92/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4273 - accuracy: 0.8021 - val_loss: 0.4433 - val_accuracy: 0.8125
# Epoch 93/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4264 - accuracy: 0.8003 - val_loss: 0.4452 - val_accuracy: 0.8177
# Epoch 94/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4267 - accuracy: 0.8038 - val_loss: 0.4453 - val_accuracy: 0.8125
# Epoch 95/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4256 - accuracy: 0.8073 - val_loss: 0.4446 - val_accuracy: 0.8073
# Epoch 96/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4258 - accuracy: 0.8073 - val_loss: 0.4448 - val_accuracy: 0.8073
# Epoch 97/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4261 - accuracy: 0.8038 - val_loss: 0.4453 - val_accuracy: 0.8021
# Epoch 98/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4254 - accuracy: 0.8073 - val_loss: 0.4462 - val_accuracy: 0.8073
# Epoch 99/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4263 - accuracy: 0.8038 - val_loss: 0.4460 - val_accuracy: 0.8177
# Epoch 100/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4253 - accuracy: 0.8108 - val_loss: 0.4460 - val_accuracy: 0.8125
# Epoch 101/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4253 - accuracy: 0.8108 - val_loss: 0.4470 - val_accuracy: 0.8177
# Epoch 102/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4252 - accuracy: 0.8090 - val_loss: 0.4465 - val_accuracy: 0.8073
# Epoch 103/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4252 - accuracy: 0.8056 - val_loss: 0.4463 - val_accuracy: 0.8177
# Epoch 104/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4248 - accuracy: 0.8056 - val_loss: 0.4482 - val_accuracy: 0.8125
# Epoch 105/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4246 - accuracy: 0.8056 - val_loss: 0.4480 - val_accuracy: 0.8177
# Epoch 106/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4241 - accuracy: 0.8056 - val_loss: 0.4472 - val_accuracy: 0.8125
# Epoch 107/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4240 - accuracy: 0.8090 - val_loss: 0.4481 - val_accuracy: 0.8177
# Epoch 108/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4240 - accuracy: 0.8021 - val_loss: 0.4487 - val_accuracy: 0.8177
# Epoch 109/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4237 - accuracy: 0.8021 - val_loss: 0.4480 - val_accuracy: 0.8177
# Epoch 110/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4237 - accuracy: 0.8073 - val_loss: 0.4482 - val_accuracy: 0.8125
# Epoch 111/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4237 - accuracy: 0.8090 - val_loss: 0.4477 - val_accuracy: 0.8125
# Epoch 112/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4237 - accuracy: 0.8056 - val_loss: 0.4474 - val_accuracy: 0.8125
# Epoch 113/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4232 - accuracy: 0.8038 - val_loss: 0.4482 - val_accuracy: 0.8125
# Epoch 114/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4231 - accuracy: 0.8038 - val_loss: 0.4502 - val_accuracy: 0.8177
# Epoch 115/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4233 - accuracy: 0.8056 - val_loss: 0.4485 - val_accuracy: 0.8177
# Epoch 116/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4228 - accuracy: 0.8038 - val_loss: 0.4493 - val_accuracy: 0.8177
# Epoch 117/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4227 - accuracy: 0.8073 - val_loss: 0.4496 - val_accuracy: 0.8177
# Epoch 118/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4232 - accuracy: 0.8056 - val_loss: 0.4502 - val_accuracy: 0.8177
# Epoch 119/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4225 - accuracy: 0.8021 - val_loss: 0.4493 - val_accuracy: 0.8073
# Epoch 120/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4224 - accuracy: 0.8073 - val_loss: 0.4489 - val_accuracy: 0.8125
# Epoch 121/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4222 - accuracy: 0.8090 - val_loss: 0.4482 - val_accuracy: 0.8125
# Epoch 122/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4228 - accuracy: 0.8021 - val_loss: 0.4493 - val_accuracy: 0.8125
# Epoch 123/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4224 - accuracy: 0.8038 - val_loss: 0.4498 - val_accuracy: 0.8125
# Epoch 124/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4226 - accuracy: 0.8021 - val_loss: 0.4501 - val_accuracy: 0.8125
# Epoch 125/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4218 - accuracy: 0.8038 - val_loss: 0.4493 - val_accuracy: 0.8125
# Epoch 126/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4217 - accuracy: 0.8021 - val_loss: 0.4495 - val_accuracy: 0.8125
# Epoch 127/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4215 - accuracy: 0.8090 - val_loss: 0.4502 - val_accuracy: 0.8125
# Epoch 128/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4213 - accuracy: 0.8073 - val_loss: 0.4497 - val_accuracy: 0.8125
# Epoch 129/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4210 - accuracy: 0.8056 - val_loss: 0.4503 - val_accuracy: 0.8125
# Epoch 130/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4210 - accuracy: 0.8073 - val_loss: 0.4506 - val_accuracy: 0.8125
# Epoch 131/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4207 - accuracy: 0.8090 - val_loss: 0.4506 - val_accuracy: 0.8125
# Epoch 132/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4218 - accuracy: 0.8056 - val_loss: 0.4514 - val_accuracy: 0.8125
# Epoch 133/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4213 - accuracy: 0.8073 - val_loss: 0.4505 - val_accuracy: 0.8125
# Epoch 134/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4209 - accuracy: 0.8038 - val_loss: 0.4524 - val_accuracy: 0.8125
# Epoch 135/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4209 - accuracy: 0.8038 - val_loss: 0.4518 - val_accuracy: 0.8125
# Epoch 136/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4204 - accuracy: 0.8108 - val_loss: 0.4513 - val_accuracy: 0.8125
# Epoch 137/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4203 - accuracy: 0.8073 - val_loss: 0.4524 - val_accuracy: 0.8125
# Epoch 138/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4203 - accuracy: 0.8073 - val_loss: 0.4525 - val_accuracy: 0.8125
# Epoch 139/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4196 - accuracy: 0.8108 - val_loss: 0.4519 - val_accuracy: 0.8125
# Epoch 140/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4193 - accuracy: 0.8108 - val_loss: 0.4533 - val_accuracy: 0.8125
# Epoch 141/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4195 - accuracy: 0.8038 - val_loss: 0.4516 - val_accuracy: 0.8125
# Epoch 142/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4200 - accuracy: 0.8038 - val_loss: 0.4532 - val_accuracy: 0.8125
# Epoch 143/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4192 - accuracy: 0.8090 - val_loss: 0.4529 - val_accuracy: 0.8125
# Epoch 144/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4189 - accuracy: 0.8056 - val_loss: 0.4539 - val_accuracy: 0.8125
# Epoch 145/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4186 - accuracy: 0.8073 - val_loss: 0.4532 - val_accuracy: 0.8125
# Epoch 146/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4186 - accuracy: 0.8056 - val_loss: 0.4534 - val_accuracy: 0.8125
# Epoch 147/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4186 - accuracy: 0.8073 - val_loss: 0.4545 - val_accuracy: 0.8125
# Epoch 148/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4183 - accuracy: 0.8038 - val_loss: 0.4545 - val_accuracy: 0.8125
# Epoch 149/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4185 - accuracy: 0.8056 - val_loss: 0.4529 - val_accuracy: 0.8125
# Epoch 150/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4184 - accuracy: 0.8073 - val_loss: 0.4554 - val_accuracy: 0.8177

# %%
# Make some nice plots

from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Experimentation
#
# Using what you know so far, try to make the best possible model to predict diabetes with these data.
#
# Things to try:
#
# * Try normalizing data (all values between 0 and 1)
#     ```python
#     # Normalize data - all between 0 and 1
#     scaler = MinMaxScaler()
#     X = scaler.fit_transform(X)
#     ```
# * Adding layers
# * Adjusting the number of neurons per layer (you do need to get back to 1 with a sigmoid activation at the end)
# * Different activation functions
# * Adjusting the number of epochs
# * Adjusting learning rate
