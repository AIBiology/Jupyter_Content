# %% [markdown]
# # From neuron to neural net
#
# Last time, we looked at a single neuron. We discussed the parallels between that neuron with two weights and linear regression. As we add more features (columns in our X matrix) we can add more neurons.
#
# ## Activation Functions
#
# But, as we add neurons, each neuron is still mostly functioning like linear regression. The next thing we can add to our neuron is an **activation function**. Activation functions adjust the output of a neuron by adding some function before the final output. Below are the "linear" activation function that we have modeled so far, plus the more common **ReLU (Rectified Linear Unit)** and **Sigmoid** activation functions.
#
# ![Diagrams of the linear, ReLU and Sigmoid activation functions](images/Activation_function_diagrams.png)
#
#
# Again, the activation function is applied to the output of a neuron and is a hyperparameter of the model. In practice, while layers may use different activation functions, the same function is applied to **all neurons** of each layer. Below is a single neuron, with the a couple possible activation functions.
#
# ![Diagram of a neuron with activation function](images/Activation_function.png)
#
# ## Layers
#
# As we get multiple neurons, we need some way of coordinating their output, so we can add a layer to gather the output from multiple neurons into the needed number of outputs (more on that later). But the other thing that layers do is allow deeper networks with multiple layers, each selected for functional or empirical reasons. This is where deep learning gets its name--as networks grow to have more and more layers of neurons, we refer to them as deep networks--there is no agreed upon cutoff here...more than three???
#
# ![A two layer neural network](images/Neural_network.png)

# %%
import tensorflow as tf
import pandas as pd
import numpy as np

from tensorflow import keras
from tensorflow.keras import layers

# %%
df = pd.read_csv('data/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Get our X and y
X = df.drop(columns='Outcome')
y = df['Outcome']

# %%
model = keras.Sequential([
    layers.Dense(8, input_dim=8, activation='relu'),
    layers.Dense(1, activation='sigmoid')
    ])

model.summary()
# Out:
# 2022-02-28 07:58:38.922319: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 8)                 72
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 81
# Trainable params: 81
# Non-trainable params: 0
# _________________________________________________________________
# 2022-02-28 07:58:39.937373: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79125 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:07:00.0, compute capability: 8.0

# %%
# Set some model hyperparameters
from tensorflow.keras.optimizers import Adam

lr = 0.001  # Set the learning rate. Start with default for Adam, 0.001
optimizer = Adam(learning_rate=lr)  # Set the optimizer. Start with adam.

# Compile the model--a necessary step with Keras models
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
# Now we can fit the model
# Let's also save the training history for plotting

history = model.fit(X, y, epochs=150, validation_split=0.25, batch_size=10, verbose=1)
# Out:
# Epoch 1/150
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4964 - accuracy: 0.7569 - val_loss: 0.5197 - val_accuracy: 0.7760
# Epoch 2/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4974 - accuracy: 0.7569 - val_loss: 0.5180 - val_accuracy: 0.7708
# Epoch 3/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4937 - accuracy: 0.7587 - val_loss: 0.5168 - val_accuracy: 0.7708
# Epoch 4/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4950 - accuracy: 0.7587 - val_loss: 0.5194 - val_accuracy: 0.7865
# Epoch 5/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4929 - accuracy: 0.7622 - val_loss: 0.5222 - val_accuracy: 0.7812
# Epoch 6/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4957 - accuracy: 0.7517 - val_loss: 0.5258 - val_accuracy: 0.7865
# Epoch 7/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4921 - accuracy: 0.7622 - val_loss: 0.5316 - val_accuracy: 0.7552
# Epoch 8/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4935 - accuracy: 0.7535 - val_loss: 0.5215 - val_accuracy: 0.7917
# Epoch 9/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4882 - accuracy: 0.7569 - val_loss: 0.5218 - val_accuracy: 0.7865
# Epoch 10/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4885 - accuracy: 0.7622 - val_loss: 0.5198 - val_accuracy: 0.7812
# Epoch 11/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4872 - accuracy: 0.7639 - val_loss: 0.5227 - val_accuracy: 0.7917
# Epoch 12/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4917 - accuracy: 0.7569 - val_loss: 0.5275 - val_accuracy: 0.7865
# Epoch 13/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4887 - accuracy: 0.7587 - val_loss: 0.5402 - val_accuracy: 0.7812
# Epoch 14/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4875 - accuracy: 0.7656 - val_loss: 0.5505 - val_accuracy: 0.7708
# Epoch 15/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4849 - accuracy: 0.7639 - val_loss: 0.5542 - val_accuracy: 0.7604
# Epoch 16/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4815 - accuracy: 0.7639 - val_loss: 0.5353 - val_accuracy: 0.7760
# Epoch 17/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4829 - accuracy: 0.7622 - val_loss: 0.5398 - val_accuracy: 0.7708
# Epoch 18/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4835 - accuracy: 0.7656 - val_loss: 0.5475 - val_accuracy: 0.7604
# Epoch 19/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4804 - accuracy: 0.7604 - val_loss: 0.5408 - val_accuracy: 0.7656
# Epoch 20/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4790 - accuracy: 0.7674 - val_loss: 0.5496 - val_accuracy: 0.7708
# Epoch 21/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4834 - accuracy: 0.7604 - val_loss: 0.5512 - val_accuracy: 0.7656
# Epoch 22/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4826 - accuracy: 0.7656 - val_loss: 0.5450 - val_accuracy: 0.7708
# Epoch 23/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4802 - accuracy: 0.7639 - val_loss: 0.5395 - val_accuracy: 0.7760
# Epoch 24/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4778 - accuracy: 0.7708 - val_loss: 0.5466 - val_accuracy: 0.7656
# Epoch 25/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4764 - accuracy: 0.7587 - val_loss: 0.5428 - val_accuracy: 0.7656
# Epoch 26/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4772 - accuracy: 0.7656 - val_loss: 0.5396 - val_accuracy: 0.7708
# Epoch 27/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4760 - accuracy: 0.7795 - val_loss: 0.5479 - val_accuracy: 0.7760
# Epoch 28/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4788 - accuracy: 0.7639 - val_loss: 0.5435 - val_accuracy: 0.7656
# Epoch 29/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4782 - accuracy: 0.7778 - val_loss: 0.5488 - val_accuracy: 0.7656
# Epoch 30/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4754 - accuracy: 0.7691 - val_loss: 0.5534 - val_accuracy: 0.7604
# Epoch 31/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4764 - accuracy: 0.7691 - val_loss: 0.5374 - val_accuracy: 0.7708
# Epoch 32/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4751 - accuracy: 0.7708 - val_loss: 0.5433 - val_accuracy: 0.7708
# Epoch 33/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4725 - accuracy: 0.7691 - val_loss: 0.5523 - val_accuracy: 0.7552
# Epoch 34/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4778 - accuracy: 0.7604 - val_loss: 0.5396 - val_accuracy: 0.7604
# Epoch 35/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4716 - accuracy: 0.7743 - val_loss: 0.5436 - val_accuracy: 0.7708
# Epoch 36/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4749 - accuracy: 0.7691 - val_loss: 0.5358 - val_accuracy: 0.7812
# Epoch 37/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4731 - accuracy: 0.7691 - val_loss: 0.5360 - val_accuracy: 0.7760
# Epoch 38/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4718 - accuracy: 0.7708 - val_loss: 0.5429 - val_accuracy: 0.7708
# Epoch 39/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4741 - accuracy: 0.7726 - val_loss: 0.5379 - val_accuracy: 0.7708
# Epoch 40/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4764 - accuracy: 0.7674 - val_loss: 0.5568 - val_accuracy: 0.7500
# Epoch 41/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4735 - accuracy: 0.7795 - val_loss: 0.5487 - val_accuracy: 0.7448
# Epoch 42/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4694 - accuracy: 0.7778 - val_loss: 0.5359 - val_accuracy: 0.7708
# Epoch 43/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4752 - accuracy: 0.7656 - val_loss: 0.5346 - val_accuracy: 0.7812
# Epoch 44/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4747 - accuracy: 0.7708 - val_loss: 0.5427 - val_accuracy: 0.7708
# Epoch 45/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4731 - accuracy: 0.7795 - val_loss: 0.5394 - val_accuracy: 0.7656
# Epoch 46/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4720 - accuracy: 0.7743 - val_loss: 0.5350 - val_accuracy: 0.7708
# Epoch 47/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4698 - accuracy: 0.7726 - val_loss: 0.5467 - val_accuracy: 0.7656
# Epoch 48/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4707 - accuracy: 0.7726 - val_loss: 0.5353 - val_accuracy: 0.7708
# Epoch 49/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4708 - accuracy: 0.7726 - val_loss: 0.5501 - val_accuracy: 0.7552
# Epoch 50/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4729 - accuracy: 0.7674 - val_loss: 0.5484 - val_accuracy: 0.7604
# Epoch 51/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4705 - accuracy: 0.7847 - val_loss: 0.5355 - val_accuracy: 0.7760
# Epoch 52/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4718 - accuracy: 0.7691 - val_loss: 0.5397 - val_accuracy: 0.7708
# Epoch 53/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4690 - accuracy: 0.7760 - val_loss: 0.5558 - val_accuracy: 0.7552
# Epoch 54/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4716 - accuracy: 0.7743 - val_loss: 0.5391 - val_accuracy: 0.7656
# Epoch 55/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4711 - accuracy: 0.7760 - val_loss: 0.5373 - val_accuracy: 0.7656
# Epoch 56/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4715 - accuracy: 0.7708 - val_loss: 0.5355 - val_accuracy: 0.7708
# Epoch 57/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4689 - accuracy: 0.7726 - val_loss: 0.5440 - val_accuracy: 0.7708
# Epoch 58/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4732 - accuracy: 0.7760 - val_loss: 0.5391 - val_accuracy: 0.7760
# Epoch 59/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4668 - accuracy: 0.7917 - val_loss: 0.5574 - val_accuracy: 0.7448
# Epoch 60/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4704 - accuracy: 0.7778 - val_loss: 0.5374 - val_accuracy: 0.7760
# Epoch 61/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4714 - accuracy: 0.7708 - val_loss: 0.5435 - val_accuracy: 0.7760
# Epoch 62/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4680 - accuracy: 0.7760 - val_loss: 0.5379 - val_accuracy: 0.7812
# Epoch 63/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4697 - accuracy: 0.7778 - val_loss: 0.5405 - val_accuracy: 0.7760
# Epoch 64/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4718 - accuracy: 0.7726 - val_loss: 0.5435 - val_accuracy: 0.7760
# Epoch 65/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4717 - accuracy: 0.7708 - val_loss: 0.5381 - val_accuracy: 0.7760
# Epoch 66/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4681 - accuracy: 0.7708 - val_loss: 0.5347 - val_accuracy: 0.7708
# Epoch 67/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4678 - accuracy: 0.7760 - val_loss: 0.5514 - val_accuracy: 0.7552
# Epoch 68/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4692 - accuracy: 0.7760 - val_loss: 0.5362 - val_accuracy: 0.7760
# Epoch 69/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4668 - accuracy: 0.7795 - val_loss: 0.5401 - val_accuracy: 0.7760
# Epoch 70/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4687 - accuracy: 0.7830 - val_loss: 0.5348 - val_accuracy: 0.7656
# Epoch 71/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4718 - accuracy: 0.7656 - val_loss: 0.5422 - val_accuracy: 0.7552
# Epoch 72/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4681 - accuracy: 0.7812 - val_loss: 0.5502 - val_accuracy: 0.7552
# Epoch 73/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4695 - accuracy: 0.7743 - val_loss: 0.5358 - val_accuracy: 0.7708
# Epoch 74/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4668 - accuracy: 0.7795 - val_loss: 0.5488 - val_accuracy: 0.7552
# Epoch 75/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4645 - accuracy: 0.7743 - val_loss: 0.5362 - val_accuracy: 0.7812
# Epoch 76/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4724 - accuracy: 0.7865 - val_loss: 0.5403 - val_accuracy: 0.7552
# Epoch 77/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4696 - accuracy: 0.7865 - val_loss: 0.5468 - val_accuracy: 0.7552
# Epoch 78/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4654 - accuracy: 0.7847 - val_loss: 0.5350 - val_accuracy: 0.7604
# Epoch 79/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4685 - accuracy: 0.7778 - val_loss: 0.5365 - val_accuracy: 0.7708
# Epoch 80/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4698 - accuracy: 0.7795 - val_loss: 0.5353 - val_accuracy: 0.7708
# Epoch 81/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4696 - accuracy: 0.7743 - val_loss: 0.5341 - val_accuracy: 0.7812
# Epoch 82/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4684 - accuracy: 0.7795 - val_loss: 0.5433 - val_accuracy: 0.7604
# Epoch 83/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4704 - accuracy: 0.7760 - val_loss: 0.5640 - val_accuracy: 0.7448
# Epoch 84/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4696 - accuracy: 0.7795 - val_loss: 0.5461 - val_accuracy: 0.7552
# Epoch 85/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4709 - accuracy: 0.7795 - val_loss: 0.5654 - val_accuracy: 0.7344
# Epoch 86/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4682 - accuracy: 0.7795 - val_loss: 0.5509 - val_accuracy: 0.7552
# Epoch 87/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4678 - accuracy: 0.7760 - val_loss: 0.5358 - val_accuracy: 0.7760
# Epoch 88/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4658 - accuracy: 0.7760 - val_loss: 0.5351 - val_accuracy: 0.7708
# Epoch 89/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4667 - accuracy: 0.7760 - val_loss: 0.5339 - val_accuracy: 0.7708
# Epoch 90/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4676 - accuracy: 0.7726 - val_loss: 0.5403 - val_accuracy: 0.7812
# Epoch 91/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4684 - accuracy: 0.7847 - val_loss: 0.5323 - val_accuracy: 0.7708
# Epoch 92/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4687 - accuracy: 0.7882 - val_loss: 0.5372 - val_accuracy: 0.7760
# Epoch 93/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4655 - accuracy: 0.7812 - val_loss: 0.5373 - val_accuracy: 0.7656
# Epoch 94/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4645 - accuracy: 0.7847 - val_loss: 0.5415 - val_accuracy: 0.7708
# Epoch 95/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4708 - accuracy: 0.7760 - val_loss: 0.5340 - val_accuracy: 0.7708
# Epoch 96/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4644 - accuracy: 0.7847 - val_loss: 0.5458 - val_accuracy: 0.7448
# Epoch 97/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4676 - accuracy: 0.7726 - val_loss: 0.5386 - val_accuracy: 0.7604
# Epoch 98/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4677 - accuracy: 0.7812 - val_loss: 0.5460 - val_accuracy: 0.7552
# Epoch 99/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4703 - accuracy: 0.7917 - val_loss: 0.5509 - val_accuracy: 0.7448
# Epoch 100/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4641 - accuracy: 0.7778 - val_loss: 0.5379 - val_accuracy: 0.7812
# Epoch 101/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4642 - accuracy: 0.7847 - val_loss: 0.5419 - val_accuracy: 0.7708
# Epoch 102/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4640 - accuracy: 0.7795 - val_loss: 0.5396 - val_accuracy: 0.7708
# Epoch 103/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4661 - accuracy: 0.7760 - val_loss: 0.5354 - val_accuracy: 0.7708
# Epoch 104/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4665 - accuracy: 0.7812 - val_loss: 0.5463 - val_accuracy: 0.7448
# Epoch 105/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4642 - accuracy: 0.7934 - val_loss: 0.5465 - val_accuracy: 0.7500
# Epoch 106/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4666 - accuracy: 0.7865 - val_loss: 0.5400 - val_accuracy: 0.7708
# Epoch 107/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4639 - accuracy: 0.7830 - val_loss: 0.5331 - val_accuracy: 0.7656
# Epoch 108/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4659 - accuracy: 0.7812 - val_loss: 0.5629 - val_accuracy: 0.7448
# Epoch 109/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4635 - accuracy: 0.7847 - val_loss: 0.5328 - val_accuracy: 0.7552
# Epoch 110/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4647 - accuracy: 0.7899 - val_loss: 0.5353 - val_accuracy: 0.7604
# Epoch 111/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4636 - accuracy: 0.7847 - val_loss: 0.5406 - val_accuracy: 0.7604
# Epoch 112/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4628 - accuracy: 0.7795 - val_loss: 0.5463 - val_accuracy: 0.7448
# Epoch 113/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4684 - accuracy: 0.7812 - val_loss: 0.5562 - val_accuracy: 0.7500
# Epoch 114/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4662 - accuracy: 0.7865 - val_loss: 0.5370 - val_accuracy: 0.7760
# Epoch 115/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4639 - accuracy: 0.7795 - val_loss: 0.5379 - val_accuracy: 0.7708
# Epoch 116/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4644 - accuracy: 0.7865 - val_loss: 0.5464 - val_accuracy: 0.7552
# Epoch 117/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4657 - accuracy: 0.7812 - val_loss: 0.5384 - val_accuracy: 0.7708
# Epoch 118/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4626 - accuracy: 0.7830 - val_loss: 0.5342 - val_accuracy: 0.7656
# Epoch 119/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4647 - accuracy: 0.7830 - val_loss: 0.5410 - val_accuracy: 0.7500
# Epoch 120/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4643 - accuracy: 0.7795 - val_loss: 0.5359 - val_accuracy: 0.7656
# Epoch 121/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4672 - accuracy: 0.7830 - val_loss: 0.5468 - val_accuracy: 0.7500
# Epoch 122/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4626 - accuracy: 0.7830 - val_loss: 0.5358 - val_accuracy: 0.7552
# Epoch 123/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4628 - accuracy: 0.7882 - val_loss: 0.5418 - val_accuracy: 0.7656
# Epoch 124/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4670 - accuracy: 0.7847 - val_loss: 0.5435 - val_accuracy: 0.7500
# Epoch 125/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4640 - accuracy: 0.7795 - val_loss: 0.5397 - val_accuracy: 0.7604
# Epoch 126/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4613 - accuracy: 0.7795 - val_loss: 0.5331 - val_accuracy: 0.7656
# Epoch 127/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4624 - accuracy: 0.7986 - val_loss: 0.5424 - val_accuracy: 0.7448
# Epoch 128/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4634 - accuracy: 0.7951 - val_loss: 0.5353 - val_accuracy: 0.7552
# Epoch 129/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4614 - accuracy: 0.7847 - val_loss: 0.5469 - val_accuracy: 0.7448
# Epoch 130/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4605 - accuracy: 0.7795 - val_loss: 0.5332 - val_accuracy: 0.7708
# Epoch 131/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4611 - accuracy: 0.7865 - val_loss: 0.5597 - val_accuracy: 0.7448
# Epoch 132/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4625 - accuracy: 0.7830 - val_loss: 0.5352 - val_accuracy: 0.7604
# Epoch 133/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4617 - accuracy: 0.7830 - val_loss: 0.5365 - val_accuracy: 0.7760
# Epoch 134/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4611 - accuracy: 0.7865 - val_loss: 0.5325 - val_accuracy: 0.7604
# Epoch 135/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4620 - accuracy: 0.7812 - val_loss: 0.5434 - val_accuracy: 0.7448
# Epoch 136/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4610 - accuracy: 0.7899 - val_loss: 0.5368 - val_accuracy: 0.7552
# Epoch 137/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4635 - accuracy: 0.7847 - val_loss: 0.5364 - val_accuracy: 0.7500
# Epoch 138/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4598 - accuracy: 0.7830 - val_loss: 0.5324 - val_accuracy: 0.7656
# Epoch 139/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4680 - accuracy: 0.7847 - val_loss: 0.5435 - val_accuracy: 0.7448
# Epoch 140/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4622 - accuracy: 0.7882 - val_loss: 0.5314 - val_accuracy: 0.7708
# Epoch 141/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4578 - accuracy: 0.7830 - val_loss: 0.5420 - val_accuracy: 0.7448
# Epoch 142/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4606 - accuracy: 0.7865 - val_loss: 0.5384 - val_accuracy: 0.7604
# Epoch 143/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4613 - accuracy: 0.7847 - val_loss: 0.5416 - val_accuracy: 0.7448
# Epoch 144/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4591 - accuracy: 0.7865 - val_loss: 0.5359 - val_accuracy: 0.7604
# Epoch 145/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4613 - accuracy: 0.7760 - val_loss: 0.5329 - val_accuracy: 0.7552
# Epoch 146/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4621 - accuracy: 0.7865 - val_loss: 0.5412 - val_accuracy: 0.7500
# Epoch 147/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4659 - accuracy: 0.7812 - val_loss: 0.5404 - val_accuracy: 0.7604
# Epoch 148/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4606 - accuracy: 0.7917 - val_loss: 0.5353 - val_accuracy: 0.7500
# Epoch 149/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4628 - accuracy: 0.7882 - val_loss: 0.5318 - val_accuracy: 0.7604
# Epoch 150/150
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4631 - accuracy: 0.7899 - val_loss: 0.5318 - val_accuracy: 0.7656

# %%
# Make some nice plots

from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Experimentation
#
# Using what you know so far, try to make the best possible model to predict diabetes with these data.
#
# Things to try:
#
# * Adding layers
# * Adjusting the number of neurons per layer (you do need to get back to 1 with a sigmoid activation at the end)
# * Different activation functions
# * Adjusting the number of epochs
# * Adjusting learning rate
